# %%
import praw
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime



def initReddit():
    # init API
    print "starting up reddit api"
    reddit = praw.Reddit(client_id='jAdMtveNKrDi9g',
                         client_secret='6LFxnKmAM-M_fFb6aE83-FZLvQU',
                         user_agent='python:com.example.commentcounter:v1.0.0')
    print "reddit API initialized"
    return reddit

def getSubmissions(unix_date, reddit):
    # pull submissions
    submissions = reddit.subreddit('EthTrader').submissions(start = unix_date, 
                                                            end = unix_date + 86400) #make top instead of hot
    # set total comment/score counters
    print "retrieved"
    return submissions


# Super Score Calculator
def superScore(title, comment_ct, score, sentiment_dict):
    multiplier = (1.0 - (5 * sentiment_dict['neg']) + (5 * sentiment_dict['pos']))
    super_score = (comment_ct + score) * multiplier
    
    def printScore():
        print '*******    string: ', submission.title
        print '*******  comments: ', len(submission.comments)
        print '*******     score: ', submission.score
        print "*********** negative: ", sentiment_dict['neg']
        print "***********  neutral: ", sentiment_dict['neu']
        print "*********** positive: ", sentiment_dict['pos']
        print "multiplier: ", multiplier
        print "SUPERSCORE: ", super_score
        print '\n'
   
    return super_score

#Sentiment Analysis
def sentiment(string):
    sid = SIA()
    return sid.polarity_scores(string)





def score(submission_obj): 
    for submission in submissions:
        #totalComments = 0
        #totalScore = 0
        #totalComments += len(submission.comments)
        #totalScore += submission.score
        print submission.title
        superScore(submission, sentiment(submission.title))

print "start"

counter = 0
reddit = initReddit()
date = 1493596800
submissions = getSubmissions(date, reddit) # start may 1st



#score(submissions)     

#print submissions

titles = []
scores = []
comments = []
super_scores = []
dates = []


for i in range(0, 150):
    
    date = 1493596800 + (86400 * i)

    print 'date:', datetime.datetime.utcfromtimestamp(date)
    #retrieve data
    reddit = initReddit()
    submissions = getSubmissions(date, reddit)
    
    # create arrays to be added to pandas
    print 'scraping and scoring...'
    for submission in submissions:
        title = submission.title
        score = submission.score
        len_comments = len(submission.comments)
        titles.append(title)
        scores.append(score)
        comments.append(len_comments)
        super_scores.append(superScore(title, len_comments, score, sentiment(title)))
        dates.append(datetime.datetime.utcfromtimestamp(date))
    


df = pd.DataFrame({
                    #'date': pd.Timestamp('20130102'), 
                    'title': titles,
                    'score': scores,
                    'comments': comments,
                    'date': dates,
                    'super_scores' : super_scores
                  })


df
# Out:
# start
# starting up reddit api
# reddit API initialized
# retrieved
# date: 2017-05-01 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-02 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-03 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-04 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-05 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-06 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-07 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-08 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-09 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-10 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-11 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-12 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-13 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-14 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-15 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-16 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-17 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-18 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-19 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-20 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-21 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-22 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-23 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-24 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-25 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-26 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-27 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-28 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-29 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-30 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-05-31 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-01 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-02 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-03 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-04 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-05 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-06 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-07 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-08 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-09 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-10 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-11 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-12 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-13 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-14 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-15 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-16 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-17 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-18 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-19 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-20 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-21 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-22 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-23 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-24 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-25 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-26 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-27 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-28 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-29 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-06-30 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-01 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-02 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-03 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-04 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-05 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-06 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-07 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-08 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-09 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-10 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-11 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-12 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-13 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-14 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-15 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-16 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-17 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-18 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-19 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-20 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-21 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-22 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-23 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-24 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-25 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-26 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-27 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-28 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-29 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-30 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-07-31 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-01 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-02 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-03 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-04 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-05 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-06 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-07 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-08 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-09 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-10 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-11 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-12 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-13 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-14 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-15 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-16 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-17 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-18 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-19 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-20 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-21 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-22 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-23 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-24 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-25 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-26 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-27 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-28 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-29 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-30 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-08-31 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-01 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-02 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-03 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-04 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-05 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-06 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-07 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-08 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-09 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-10 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-11 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-12 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-13 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-14 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-15 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-16 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-17 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-18 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-19 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-20 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-21 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-22 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-23 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-24 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-25 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-26 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
# date: 2017-09-27 00:00:00
# starting up reddit api
# reddit API initialized
# retrieved
# scraping and scoring...
#        comments       date  score  super_scores  \
# 0             9 2017-05-01    102       111.000
# 1             1 2017-05-01      4         5.000
# 2             0 2017-05-01      1         1.000
# 3             1 2017-05-01      2         3.000
# 4             0 2017-05-01     12        12.000
# 5             2 2017-05-01      3         5.000
# 6             1 2017-05-01      0         1.000
# 7             3 2017-05-01     10        13.000
# 8             2 2017-05-01     17        19.000
# 9             0 2017-05-01     16        16.000
# 10           13 2017-05-01      6        19.000
# 11           31 2017-05-01    330       361.000
# 12            2 2017-05-01      1         3.000
# 13            3 2017-05-01     16        19.000
# 14           49 2017-05-01     69       118.000
# 15            1 2017-05-01      3         4.000
# 16            3 2017-05-01     59        62.000
# 17            1 2017-05-01      8         9.000
# 18            0 2017-05-01      2         4.000
# 19           10 2017-05-01      0        10.000
# 20            3 2017-05-01      1         4.000
# 21            2 2017-05-01      0         3.920
# 22            2 2017-05-01      1         3.000
# 23            0 2017-05-01      3         7.275
# 24            1 2017-05-01      1         0.390
# 25            7 2017-05-01    104       169.830
# 26            2 2017-05-01      1         3.000
# 27            0 2017-05-01     14        14.000
# 28            3 2017-05-01      1        -0.260
# 29           12 2017-05-01      4        16.000
# ...         ...        ...    ...           ...
# 18305         4 2017-09-27     36        66.000
# 18306         6 2017-09-27    255       632.925
# 18307         0 2017-09-27      1         1.000
# 18308         0 2017-09-27      2         1.880
# 18309         1 2017-09-27      1        -2.740
# 18310         2 2017-09-27      1         3.000
# 18311        16 2017-09-27     99       115.000
# 18312         0 2017-09-27      5        -1.400
# 18313         0 2017-09-27      2         2.000
# 18314         0 2017-09-27      3         3.000
# 18315         1 2017-09-27      4        10.325
# 18316        71 2017-09-27     33       104.000
# 18317       254 2017-09-27    287       541.000
# 18318        10 2017-09-27    100       375.650
# 18319         0 2017-09-27      0         0.000
# 18320        10 2017-09-27     24        25.670
# 18321        12 2017-09-27     81        93.000
# 18322         2 2017-09-27      5       -10.780
# 18323         3 2017-09-27      0         3.000
# 18324         0 2017-09-27      2         2.000
# 18325         5 2017-09-27     57       152.830
# 18326         0 2017-09-27      1         1.590
# 18327         4 2017-09-27     11        15.000
# 18328         4 2017-09-27      4        -5.320
# 18329         6 2017-09-27     91       222.615
# 18330         7 2017-09-27     23        30.000
# 18331         6 2017-09-27     41        47.000
# 18332         2 2017-09-27      4         6.000
# 18333         1 2017-09-27      6        -2.310
# 18334         2 2017-09-27      1         3.000
#
#                                                    title
# 0                     Ethereum is the AWS of blockchains
# 1                    San Diego Ethereum Meetup @ Airbitz
# 2      Market thoughts GNT, ETH, GNO, REP and Coinmar...
# 3             CoinMarketCap GNO Market Cap is Inaccurate
# 4      Ernst & Young has formed the Ops Chain to inte...
# 5                        Liquidity squeeze behind rally?
# 6                                    ELI5 Proof of Stake
# 7                        Ethereum - the next two months?
# 8                          Got interviewed by Status.IM!
# 9               HitBTC launches TIME token trading today
# 10     How much of your ETH holdings would you unload...
# 11     As an early BTC holder, this is my take on Eth...
# 12     Does circulating supply effect a cryptocurrenc...
# 13               Now just imagine one year from now.....
# 14     Just borrowed $30k to buy ETH. Stay tuned for ...
# 15                    Relationship to Ether and Ethereum
# 16     More Billionaires are Buying Cryptocurrency [I...
# 17     The higher the Ether price goes, the more mone...
# 18     Democracy on Blockchain: How CreditBit Engages...
# 19                        The dump/correction has begun.
# 20         Eli5: Why is ETC still being used and traded?
# 21     New to Ether. Still worth buying or should i w...
# 22     How long does it take to receive the net proce...
# 23     VIDEO: Bittrex on Ethereum... celebrating the ...
# 24     People who have lost private keys: How many ET...
# 25           Lambo shopping today - sorry, had to share.
# 26     [BEST RESOURCES] to learn how to trade on cryp...
# 27     Just posted my monthly fund letter for April -...
# 28     Am I insane for still having my ETH in my pre-...
# 29                 Should I loan up to buy and hold ETH?
# ...                                                  ...
# 18305  Regulated ICOs Arrive: Overstock to Open Excha...
# 18306  New SEC compliant exchange! This is good for Eth.
# 18307  Blockchain Investors Community iTuber Intervie...
# 18308  First fully proof-of-PLAY token. Mining phase ...
# 18309                         WTT Ethereum Token Problem
# 18310                    EthTrader Telegram Deactivated?
# 18311                     Metropolis effect on ETH Price
# 18312  However, the resistance will be broken in the ...
# 18313          How does the fee structure work in Augur?
# 18314  CBPM Establish Blockchain Research Institute i...
# 18315  Interested in Cryptocurrencies? There is a Job...
# 18316      Daily Altcoin Discussion - September 27, 2017
# 18317      Daily General Discussion - September 27, 2017
# 18318  Investing in ICO’s and actually turning a heal...
# 18319                             Ian Balina / ZILLA ama
# 18320  OmegaOne vs. AirSwap vs. Kyber vs. 0x. Are the...
# 18321                       My Technical Analysis of ZRX
# 18322                     Fake Twitter Account takedown.
# 18323       I have ideas, but don't know where to start.
# 18324            London hosts key ICO event 11th October
# 18325  Vitalik & TrueBit - White Paper - Solving ICO ...
# 18326  Singapore Cryptocurrency Companies Swimming In...
# 18327  Elon Musk is Seeking New Project Funding. Perh...
# 18328                    Paranoid About Storage of Coins
# 18329  Exponential Growth of 'Blockchain' Clubs at Un...
# 18330  Short video on why ETH is likely preparing for...
# 18331                                     Bullish on BAT
# 18332  Governments are testing their own cryptocurren...
# 18333  Japanese Banks Are Planning to Launch J-Coin, ...
# 18334               Decentraland LAND Rush Starts Friday
#
# [18335 rows x 5 columns]

# %%
# Out:
#      comments       date  score  super_scores  \
# 0           9 2017-05-01    106       115.000
# 1           1 2017-05-01      4         5.000
# 2           0 2017-05-01      1         1.000
# 3           1 2017-05-01      2         3.000
# 4           0 2017-05-01     12        12.000
# 5           2 2017-05-01      3         5.000
# 6           1 2017-05-01      0         1.000
# 7           3 2017-05-01     10        13.000
# 8           2 2017-05-01     17        19.000
# 9           0 2017-05-01     16        16.000
# 10         13 2017-05-01      9        22.000
# 11         31 2017-05-01    331       362.000
# 12          2 2017-05-01      1         3.000
# 13          3 2017-05-01     15        18.000
# 14         49 2017-05-01     66       115.000
# 15          1 2017-05-01      3         4.000
# 16          3 2017-05-01     58        61.000
# 17          1 2017-05-01      8         9.000
# 18          0 2017-05-01      2         4.000
# 19         10 2017-05-01      0        10.000
# 20          3 2017-05-01      1         4.000
# 21          2 2017-05-01      0         3.920
# 22          2 2017-05-01      1         3.000
# 23          0 2017-05-01      2         4.850
# 24          1 2017-05-01      1         0.390
# 25          7 2017-05-01    106       172.890
# 26          2 2017-05-01      1         3.000
# 27          0 2017-05-01     13        13.000
# 28          3 2017-05-01      1        -0.260
# 29         12 2017-05-01      3        15.000
# ..        ...        ...    ...           ...
# 581         7 2017-05-05     50        65.835
# 582         0 2017-05-05      4         9.300
# 583         1 2017-05-05      6         7.000
# 584         2 2017-05-05      0         2.000
# 585         8 2017-05-05    110       118.000
# 586         5 2017-05-05     35        40.000
# 587         0 2017-05-05      4        10.460
# 588         0 2017-05-05      3         3.000
# 589         8 2017-05-05     36        44.000
# 590         3 2017-05-05      0        -2.535
# 591         1 2017-05-05      3        11.500
# 592         2 2017-05-05     12        26.530
# 593         2 2017-05-05      3        -3.775
# 594         4 2017-05-05     71        75.000
# 595         2 2017-05-05     14        52.400
# 596         1 2017-05-05      4        -3.825
# 597         2 2017-05-05      6         8.000
# 598         2 2017-05-05      1         3.000
# 599         1 2017-05-05      0         1.000
# 600         7 2017-05-05      7        33.250
# 601         1 2017-05-05      1         2.000
# 602         1 2017-05-05      2         8.625
# 603         2 2017-05-05      3         5.000
# 604         2 2017-05-05      3         5.000
# 605         0 2017-05-05      7         7.000
# 606         3 2017-05-05      5        35.080
# 607        12 2017-05-05    288       300.000
# 608         4 2017-05-05      3        19.040
# 609         1 2017-05-05      6         7.000
# 610         2 2017-05-05      5         7.000
#
#                                                  title
# 0                   Ethereum is the AWS of blockchains
# 1                  San Diego Ethereum Meetup @ Airbitz
# 2    Market thoughts GNT, ETH, GNO, REP and Coinmar...
# 3           CoinMarketCap GNO Market Cap is Inaccurate
# 4    Ernst & Young has formed the Ops Chain to inte...
# 5                      Liquidity squeeze behind rally?
# 6                                  ELI5 Proof of Stake
# 7                      Ethereum - the next two months?
# 8                        Got interviewed by Status.IM!
# 9             HitBTC launches TIME token trading today
# 10   How much of your ETH holdings would you unload...
# 11   As an early BTC holder, this is my take on Eth...
# 12   Does circulating supply effect a cryptocurrenc...
# 13             Now just imagine one year from now.....
# 14   Just borrowed $30k to buy ETH. Stay tuned for ...
# 15                  Relationship to Ether and Ethereum
# 16   More Billionaires are Buying Cryptocurrency [I...
# 17   The higher the Ether price goes, the more mone...
# 18   Democracy on Blockchain: How CreditBit Engages...
# 19                      The dump/correction has begun.
# 20       Eli5: Why is ETC still being used and traded?
# 21   New to Ether. Still worth buying or should i w...
# 22   How long does it take to receive the net proce...
# 23   VIDEO: Bittrex on Ethereum... celebrating the ...
# 24   People who have lost private keys: How many ET...
# 25         Lambo shopping today - sorry, had to share.
# 26   [BEST RESOURCES] to learn how to trade on cryp...
# 27   Just posted my monthly fund letter for April -...
# 28   Am I insane for still having my ETH in my pre-...
# 29               Should I loan up to buy and hold ETH?
# ..                                                 ...
# 581  Remember this prediction? Well I was wrong, it...
# 582           Ethereum Co-founder on ETH reaching $100
# 583                I made a "view-only" style for GDAX
# 584  CryptoScam #8 - Ethereum Launch (w/ Jason Seib...
# 585  "The Internet of Money should not cost 5 cents...
# 586  ETH $97. DASH $95. Eth surpasses Dash (and wit...
# 587  Share & Charge- Lead By WHOM?? / ZCoin Adding ...
# 588  This App allows you to check Ethereum price fr...
# 589   Digix To Return 465,000 ETC To DGD Token Holders
# 590  Gemini Planned Maintenance on the worst possib...
# 591                 Private Blockchains and ETH Value?
# 592  Who did buy these 3,9M Ethers? Average value o...
# 593             Trouble finding ETH report on Coinbase
# 594                    To ETH Mooon!!! ┗(°0°)┛- Selfie
# 595                                ETH Once Again Like
# 596               Hodl!!!! Don't be like me in 2013!!!
# 597                                             Omhomg
# 598                      ETH finally 3 digits on Polo!
# 599          Exchanged ETH in MEW and Never Received??
# 600  I'm trying to convince a friend to invest thei...
# 601                              99 Red Balloons Go By
# 602                          $100 ETH. To the moon. :)
# 603                            ETH hits 100USD on Polo
# 604                                            $100!!!
# 605                                       I AM HODLING
# 606                              Best Ethereum wallet?
# 607                          Watching Eth approach 100
# 608  ETH noobie here...what are my best options for...
# 609                                    Make it rain...
# 610                             BTC to ETH on Coinbase
#
# [611 rows x 5 columns]

# %%
df.to_csv('raw_data.tsv', sep='\t', encoding='utf-8')

# %%
def initReddit():
    # init API
    print "retrieving"
    reddit = praw.Reddit(client_id='jAdMtveNKrDi9g',
                         client_secret='6LFxnKmAM-M_fFb6aE83-FZLvQU',
                         user_agent='python:com.example.commentcounter:v1.0.0')
    # pull submissions
    submissions = reddit.subreddit('EthTrader').hot(limit=7) #make top instead of hot
    # set total comment/score counters
    print "retrieved"
    return submissions

initReddit()
# Out:
# retrieving
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ea9c8601d267> in <module>()
#      11     return submissions
#      12
# ---> 13 initReddit()
#
# <ipython-input-4-ea9c8601d267> in initReddit()
#       2     # init API
#       3     print "retrieving"
# ----> 4     reddit = praw.Reddit(client_id='jAdMtveNKrDi9g',
#       5                          client_secret='6LFxnKmAM-M_fFb6aE83-FZLvQU',
#       6                          user_agent='python:com.example.commentcounter:v1.0.0')
#
# NameError: global name 'praw' is not defined

# %%
print "hi"
# Out:
# hi
